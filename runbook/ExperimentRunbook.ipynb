# %% [markdown]
# # Steves EXPERIMENT runbook
# This runbook is entierly for executing measured experiments not for development work

# %% [markdown]
#  0 revert colab to an earlier version - 2025.07

# %%
import sys

print("Python version:", sys.version)

# %% [markdown]
# 0.1 clone the repo

# %%
# note : only run this the first time, not after the restart
# !git clone https://github.com/sdonoghue1sheffieldacuk/Time-Series-Library-fork.git
# %cd Time-Series-Library-fork

# %% [markdown]
# 0.2 check out the branch of interest

# %%
# !git checkout exploratory1 # main line

# !git checkout Experimental-3-rescale-start-end-params

# !git pull

# %% [markdown]
# 0.3 fix up the paths so everything can be found -- these instructions are for wrangling google colab - your environment might need something different

# %%
# !pwd
# %cd Time-Series-Library-fork

# %%
import sys  # this adds the checkout to colabs path environment
sys.path.append("/content/Time-Series-Library-fork")

# %%
sys.path
# it should show /content/Time-Series-Library-fork

# %% [markdown]
# ### 1.0 - A) Install Python 3.8. For convenience, execute the following command.
# again we are wrangling colab and installing some dependencies that is doesn't really want to.
#
# this will then need a restart

# %%
pip install -r /content/Time-Series-Library-fork/requirements.txt

# %% [markdown]
# # 1.0 -B) after restarting the session run the pip install again below

# %%
pip install -r /content/Time-Series-Library-fork/requirements.txt

# %% [markdown]
# 1.1 mount the drive for safe keeping - again this is for colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2. Running the Experiment and Visualizing Result
#
# After managing the data, model well, we need to write a shell script for the experiment. In the script, we need to run `run.py` with several arguments, which is part of the configuration. Here, let's see `TimesNet` on task long-term forecast with dataset ETTh1 for example.

# %%
# !pwd
# %cd Time-Series-Library-fork/
# %mkdir dataset
# %cd dataset
# %mkdir disertation_data
# %cd ..
# %cd ..
# !pwd
# Out:
# /content
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork/dataset
# /content/Time-Series-Library-fork
# /content
# /content

# %%
# copy in some data to work on
# %cp ./drive/MyDrive/raw_dis_data/stocktraces-columnated.csv ./Time-Series-Library-fork/dataset/disertation_data/stocktraces-columnated.csv
# %cd Time-Series-Library-fork
# !pwd
# Out:
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork

# %%
#if you need to update something
# !git pull
# Out:
# Already up to date.

# %%
# this is the experiment cell for the shaped ETS former experiment
model_name="ETSformer"
# !export CUDA_VISIBLE_DEVICES=4

#%cd Time-Series-Library-fork
# !pwd

#t="$(date +""%Y%m%d-%H--%M"")"
#%mkdir /content/drive/MyDrive/UnattendedResults/$t

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path dataset/disertation_data/ \
  --data_path stocktraces-columnated.csv \
  --model_id Exchange_96_96 \
  --model $model_name\
  --data custom_multi \
  --features M \
  --seq_len 96 \
  --label_len 48 \
  --pred_len 96 \
  --e_layers 2 \
  --d_layers 2 \
  --factor 3 \
  --enc_in  4\
  --dec_in 4 \
  --attn_shape_start 1\
  --attn_shape_end 1\
  --attn_shape_power 1\
  --c_out 4 \
  --des 'Exp' \
  --itr 1


# %mv ./result_long_term_forecast.txt ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--result_long_term_forecast--ETS-gettingstarted--.txt"")"
# %mv ./complete_experiment_long_term_forecast.txt ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--ETS_getting_started_complete_experiment_long_term_forecast.txt"")"
# !find -name '*bias*' | zip biases-ets.zip -@
# !rm  *bias_history*
# !find -name 'self.fcount_*' | zip head_imgs-ets.zip -@
# !rm  *self.fcount_*
# %mv ./biases-ets.zip ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--biases-ets.zip"")"
# %mv ./head_imgs-ets.zip ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--head_imgs-ets.zip"")"
# !zip -r resultpdfs.zip ./test_results
# %mv ./resultpdfs.zip ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--resultpdfs-ets.zip"")"
# !zip -r resultnpys.zip ./results
# %mv ./resultnpys.zip ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--resultnpys-ets.zip"")"
# Out:
# /content/Time-Series-Library-fork
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           Exchange_96_96      Model:              ETSformer
#
# Data Loader
#   Data:               custom_multi        Root Path:          dataset/disertation_data/
#   Data Path:          stocktraces-columnated.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              4                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               2048
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                Exp                 Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: ETSformer ...
# creating full attention mask_flag=False, factor=3, scale=None, attention_dropout=0.1, output_attention=False
# creating full attention mask_flag=False, factor=3, scale=None, attention_dropout=0.1, output_attention=False
# >>>>>>>start training : long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0>>>>>>>>>>>>>>>>>>>>>>>>>>
# dataset/disertation_data/stocktraces-columnated.csv
# train 16406
# dataset/disertation_data/stocktraces-columnated.csv
# /content/Time-Series-Library-fork
# dataset/disertation_data/stocktraces-columnated.csv
# val 2433
# dataset/disertation_data/stocktraces-columnated.csv
# /content/Time-Series-Library-fork
# dataset/disertation_data/stocktraces-columnated.csv
# test 4372
# dataset/disertation_data/stocktraces-columnated.csv
# /content/Time-Series-Library-fork
# self.shape_start:Parameter containing:
# tensor([1.], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([1.], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# self.shape_start:Parameter containing:
# tensor([1.], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([1.], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# 	iters: 100, epoch: 1 | loss: 0.3321369
# 	speed: 0.0884s/iter; left time: 444.8542s
# 	iters: 200, epoch: 1 | loss: 0.1898502
# 	speed: 0.0689s/iter; left time: 339.8560s
# 	iters: 300, epoch: 1 | loss: 0.1654276
# 	speed: 0.0692s/iter; left time: 334.2147s
# 	iters: 400, epoch: 1 | loss: 0.1183316
# 	speed: 0.0714s/iter; left time: 337.7853s
# 	iters: 500, epoch: 1 | loss: 0.1131075
# 	speed: 0.0713s/iter; left time: 330.3165s
# self.shape_start:Parameter containing:
# tensor([0.9966], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9953], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# self.shape_start:Parameter containing:
# tensor([0.9927], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9931], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# Epoch: 1 cost time: 38.24198865890503
# Epoch: 1, Steps: 513 | Train Loss: 0.1830023 Vali Loss: 0.0328211 Test Loss: 0.0498140
# Validation loss decreased (inf --> 0.032821).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1237228
# 	speed: 0.1689s/iter; left time: 763.2345s
# 	iters: 200, epoch: 2 | loss: 0.0827430
# 	speed: 0.0717s/iter; left time: 316.6319s
# self.shape_start:Parameter containing:
# tensor([0.9951], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9943], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# self.shape_start:Parameter containing:
# tensor([0.9921], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9918], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# 	iters: 400, epoch: 6 | loss: 0.0419485
# 	speed: 0.0755s/iter; left time: 163.6294s
# 	iters: 500, epoch: 6 | loss: 0.0337620
# 	speed: 0.0738s/iter; left time: 152.5205s
# Epoch: 6 cost time: 38.60310363769531
# Epoch: 6, Steps: 513 | Train Loss: 0.0621779 Vali Loss: 0.0137178 Test Loss: 0.0312468
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.0601615
# 	speed: 0.1717s/iter; left time: 335.4058s
# self.shape_start:Parameter containing:
# tensor([0.9920], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9926], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# self.shape_start:Parameter containing:
# tensor([0.9913], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9900], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# 	iters: 200, epoch: 7 | loss: 0.0763823
# 	speed: 0.0770s/iter; left time: 142.6780s
# 	iters: 300, epoch: 7 | loss: 0.0420424
# 	speed: 0.0723s/iter; left time: 126.8053s
# 	iters: 400, epoch: 7 | loss: 0.0535453
# 	speed: 0.0740s/iter; left time: 122.3534s
# 	iters: 500, epoch: 7 | loss: 0.0636584
# 	speed: 0.0723s/iter; left time: 112.3033s
# Epoch: 7 cost time: 38.52461767196655
# self.shape_start:Parameter containing:
# tensor([0.9920], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9925], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# self.shape_start:Parameter containing:
# tensor([0.9914], device='cuda:0', requires_grad=True) 	 self.shape_end:Parameter containing:
# tensor([0.9900], device='cuda:0', requires_grad=True) 	 self._shape_power_raw : 1.0
# Epoch: 7, Steps: 513 | Train Loss: 0.0627304 Vali Loss: 0.0138828 Test Loss: 0.0306578
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# dataset/disertation_data/stocktraces-columnated.csv
# test 4372
# dataset/disertation_data/stocktraces-columnated.csv
# /content/Time-Series-Library-fork
# test shape: (4372, 96, 4) (4372, 96, 4)
# test shape: (4372, 96, 4) (4372, 96, 4)
# mse:0.027101879939436913, mae:0.11110185086727142, dtw:Not calculated
# mv: cannot stat './complete_experiment_long_term_forecast.txt': No such file or directory
#   adding: flat_encoder_positional_bias_history2.png (deflated 17%)
#   adding: flat_encoder_positional_bias_history1.png (deflated 14%)
#   adding: self.fcount_4500_20260723_144042.png (deflated 7%)
#   adding: self.fcount_2000_20260723_144042.png (deflated 10%)
#   adding: self.fcount_1500_20260723_144042.png (deflated 7%)
#   adding: self.fcount_3500_20260723_144042.png (deflated 15%)
#   adding: self.fcount_1000_20260723_144042.png (deflated 7%)
#   adding: self.fcount_3000_20260723_144042.png (deflated 7%)
#   adding: self.fcount_0_20260723_144042.png (deflated 8%)
#   adding: self.fcount_500_20260723_144042.png (deflated 7%)
#   adding: self.fcount_4000_20260723_144042.png (deflated 7%)
#   adding: self.fcount_2500_20260723_144042.png (deflated 7%)
#   adding: self.fcount_5000_20260723_144042.png (deflated 13%)
# mv: cannot stat './biases.zip': No such file or directory
# mv: cannot stat './head_imgs.zip': No such file or directory
#   adding: test_results/ (stored 0%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/ (stored 0%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/0.pdf (deflated 25%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/80.pdf (deflated 25%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/60.pdf (deflated 26%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/100.pdf (deflated 26%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/120.pdf (deflated 25%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/20.pdf (deflated 26%)
#   adding: test_results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/40.pdf (deflated 25%)
#   adding: results/ (stored 0%)
#   adding: results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/ (stored 0%)
#   adding: results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/true.npy (deflated 98%)
#   adding: results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/metrics.npy (deflated 40%)
#   adding: results/long_term_forecast_Exchange_96_96_ETSformer_custom_multi_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl2_df2048_expand2_dc4_fc3_ebtimeF_dtTrue_Exp_attn_shplinears1.0e1.0p1.0rFalse|0/pred.npy (deflated 16%)
