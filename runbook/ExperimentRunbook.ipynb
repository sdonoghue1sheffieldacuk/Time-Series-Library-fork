# %% [markdown]
# # Steves EXPERIMENT runbook
# This runbook is entierly for executing measured experiments not for development work

# %% [markdown]
#  0 revert colab to an earlier version - 2025.07

# %%
import sys

print("Python version:", sys.version)
# Out:
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %% [markdown]
# 0.1 clone the repo

# %%
# note : only run this the first time, not after the restart
# !git clone https://github.com/sdonoghue1sheffieldacuk/Time-Series-Library-fork.git
# %cd Time-Series-Library-fork
# Out:
# Cloning into 'Time-Series-Library-fork'...
# remote: Enumerating objects: 2747, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 2747 (delta 259), reused 227 (delta 220), pack-reused 2470 (from 3)
# Receiving objects: 100% (2747/2747), 78.85 MiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (1872/1872), done.
# /content/Time-Series-Library-fork

# %% [markdown]
# 0.2 check out the branch of interest

# %%
#!git checkout exploratory1 # main line

# !git checkout Experimental-3-rescale-start-end-params

# !git pull
# Out:
# Branch 'Experimental-3-rescale-start-end-params' set up to track remote branch 'Experimental-3-rescale-start-end-params' from 'origin'.
# Switched to a new branch 'Experimental-3-rescale-start-end-params'
# Already up to date.

# %% [markdown]
# 0.3 fix up the paths so everything can be found -- these instructions are for wrangling google colab - your environment might need something different

# %%
# !pwd
# %cd Time-Series-Library-fork
# Out:
# /content/Time-Series-Library-fork
# [Errno 2] No such file or directory: 'Time-Series-Library-fork'
# /content/Time-Series-Library-fork

# %%
import sys  # this adds the checkout to colabs path environment
sys.path.append("/content/Time-Series-Library-fork")

# %%
sys.path
# it should show /content/Time-Series-Library-fork
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.11/dist-packages/IPython/extensions',
#  '/usr/local/lib/python3.11/dist-packages/setuptools/_vendor',
#  '/root/.ipython',
#  '/content/Time-Series-Library-fork']

# %% [markdown]
# ### 1.0 - A) Install Python 3.8. For convenience, execute the following command.
# again we are wrangling colab and installing some dependencies that is doesn't really want to.
#
# this will then need a restart

# %%
pip install -r /content/Time-Series-Library-fork/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 111.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 130.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 125.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 1.0 -B) after restarting the session run the pip install again below

# %%
pip install -r /content/Time-Series-Library-fork/requirements.txt

# %% [markdown]
# 1.1 mount the drive for safe keeping - again this is for colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
folder = datetime.date(datetime.now())
folder  = folder.strftime("%Y-%m-%d")
# %cd drive
# %cd MyDrive
# %cd UnattendedResults
# %mkdir $folder
# %cd ..
# %cd ..
# %cd ..
#%mv ./result_long_term_forecast.txt ../drive/MyDrive/UnattendedResults/"$(date +""d=%d-h=%H+1--m=%M--result_long_term_forecast--ETS-gettingstarted--.txt"")"
# Out:
# /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/UnattendedResults
# mkdir: cannot create directory ‘2026-08-05’: File exists
# /content/drive/MyDrive
# /content/drive
# /content

# %% [markdown]
# ### 2. Running the Experiment and Visualizing Result
#
# After managing the data, model well, we need to write a shell script for the experiment. In the script, we need to run `run.py` with several arguments, which is part of the configuration. Here, let's see `TimesNet` on task long-term forecast with dataset ETTh1 for example.

# %%
# !pwd
# %cd Time-Series-Library-fork/
# %mkdir dataset
# %cd dataset
# %mkdir disertation_data
# %cd ..
# %cd ..
# !pwd
# Out:
# /content
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork/dataset
# /content/Time-Series-Library-fork
# /content
# /content

# %%
# !pwd
# %cd content
# Out:
# /content
# [Errno 2] No such file or directory: 'content'
# /content

# %%
# !pwd
# Out:
# /content/Time-Series-Library-fork

# %%
# copy in some data to work on
#%cd ..
# !pwd
# %cp /content/drive/MyDrive/experiment_sets/exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv /content/Time-Series-Library-fork/dataset/disertation_data/exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv
# !pwd
# Out:
# /content
# /content

# %%
cd /content/Time-Series-Library-fork
# Out:
# /content/Time-Series-Library-fork

# %%
#if you need to update something
# !git pull
# Out:
# Already up to date.

# %%
#exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv
def experiment(model_name, learning_rate, datafilename, data_columns,  shape_start, shape_end, shape_power):

  # this is the experiment cell for the shaped ETS former experiment
  #model_name="Transformer"
  # !export CUDA_VISIBLE_DEVICES=4

  #%cd Time-Series-Library-fork
  # !pwd

  #t="$(date +""%Y%m%d-%H--%M"")"
  #%mkdir /content/drive/MyDrive/UnattendedResults/$t

  # !python -u run.py \
    --task_name long_term_forecast \
    --is_training 1 \
    --root_path dataset/disertation_data/ \
    --data_path $datafilename \
    --model_id Exchange_96_96 \
    --model $model_name \
    --data custom_multi \
    --features M \
    --seq_len 96 \
    --label_len 48 \
    --pred_len 96 \
    --e_layers 2 \
    --d_layers 2 \
    --factor 3 \
    --enc_in $data_columns \
    --dec_in $data_columns \
    --learning_rate $learning_rate \
    --attn_shape_start $shape_start \
    --attn_shape_end $shape_end \
    --attn_shape_power $shape_power \
    --c_out $data_columns \
    --des 'Exp' \
    --itr 1

  with open("params.txt", "a") as f:
    f.write(f"run parameters model:{model_name} \nlearning_rate:{learning_rate}\n")
    f.write(f"run parameters datafilename:{datafilename} \data_columns:{data_columns}\n")
    f.write(f"run parameters shape_start:{shape_start} \shape_end:{shape_end} shape_power:{shape_power}\n")


  # %mv ./params.txt ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H-params.txt"")"
  # %mv ./result_long_term_forecast.txt ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H-result_long_term_forecast--ETS-gettingstarted--.txt"")"
  # %mv ./complete_experiment_long_term_forecast.txt ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H--ETS_getting_started_complete_experiment_long_term_forecast.txt"")"
  # !find -name '*bias*' | zip biases-ets.zip -@
  # !rm  *bias_history*
  # !find -name 'self.fcount_*' | zip head_imgs-ets.zip -@
  # !rm  *self.fcount_*
  # %mv ./biases-ets.zip ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H--biases-ets.zip"")"
  # %mv ./head_imgs-ets.zip ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H--head_imgs-ets.zip"")"
  # !zip -r resultpdfs.zip ./test_results
  # %mv ./resultpdfs.zip ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H--resultpdfs-ets.zip"")"
  # %rm ./test_results/*
  # !zip -r resultnpys.zip ./results
  # %mv ./resultnpys.zip ../drive/MyDrive/UnattendedResults/$folder/"$(date +""%m-%d_%H-%M+1H--resultnpys-ets.zip"")"

# %%
#
experiment("Transformer", 0.1, "exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.01, "exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.001, "exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.0001, "exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
# Out:
# /content/Time-Series-Library-fork
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           Exchange_96_96      Model:              Transformer
#
# Data Loader
#   Data:               custom_multi        Root Path:          dataset/disertation_data/
#   Data Path:          exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             5                   Dec In:             5
#   C Out:              5                   d model:            512
# ...

# %%
# copy in some data to work on
#%cd ..
# !pwd
# %cp /content/drive/MyDrive/experiment_sets/exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv /content/Time-Series-Library-fork/dataset/disertation_data/exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv
# !pwd
# copy in some data to work on
#%cd ..
# !pwd
# %cp /content/drive/MyDrive/experiment_sets/exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv /content/Time-Series-Library-fork/dataset/disertation_data/exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv
# !pwd
# Out:
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork
# /content/Time-Series-Library-fork

# %%
#
#experiment("Transformer", 0.1, "exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.01, "exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.001, "exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.0001, "exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv", 5,  1, 1, 1)

#
#experiment("Transformer", 0.1, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.01, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.001, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.0001, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
# Out:
# /content/Time-Series-Library-fork
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           Exchange_96_96      Model:              Transformer
#
# Data Loader
#   Data:               custom_multi        Root Path:          dataset/disertation_data/
#   Data Path:          exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             5                   Dec In:             5
#   C Out:              5                   d model:            512
# ...

# %%
experiment("Transformer", 0.0001, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
#experiment("Transformer", 0.00001, "exp_set_1AB_side_22-05-10to23-11-02_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.00001, "exp_set_2AB_bull_16-07-25to17-12-29_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
experiment("Transformer", 0.00001, "exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csv", 5,  1, 1, 1)
# Out:
# /content/Time-Series-Library-fork
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           Exchange_96_96      Model:              Transformer
#
# Data Loader
#   Data:               custom_multi        Root Path:          dataset/disertation_data/
#   Data Path:          exp_set_3AB_bear_10-04-27to11-10-25_AtoKD--200-OHLC.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             5                   Dec In:             5
#   C Out:              5                   d model:            512
# ...
